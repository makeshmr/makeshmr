# %% [markdown]
# <a href="https://colab.research.google.com/github/makeshmr/makeshmr/blob/main/BinaryTrees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DataStructures such as LL,arrays, queues, stack all store linear data.
# Sometime you have to store the information in any other form other than linear. Such Hierarcheal Data. So we need a data Structure to store hierarcheal Data strutucture to do.
#
# Exampls
# - Organization with CEOs, VPs, Managers etc...
# -  Files and Folders struture
# - Family Tree
