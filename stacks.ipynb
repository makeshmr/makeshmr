# %% [markdown]
# <a href="https://colab.research.google.com/github/makeshmr/makeshmr/blob/main/stacks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A **stack** is a data structure that store and organize data. It helps keep track of what’s happening in a program at a certain time
#
# It works like a pile where items are added to the top and also removed from the top. This means the last item added is the first one to be removed — this is called LIFO (Last In, First Out).

# %% [markdown]
# ![Screenshot 2025-04-05 at 10.26.50 AM.png](data:image/png;base64,...)

# %% [markdown]
# Operation for  stack
#
# 1. Push -> Insert at the top
# 2. Pop -> removal from the top
# 3. Peek -> retrieve the top element
# 4. Size -> Elements in the stack

# %% [markdown]
# all of the above operation are in O(1) complexity

# %%
class Stack:
    def __init__(self, capacity):
        self.capacity = capacity  # Maximum size of the stack
        self.stack = [0] * capacity  # Fixed-size array
        self.top = -1  # Index of the top element, -1 means stack is empty

    def is_empty(self):
        return self.top == -1

    def is_full(self):
        return self.top == self.capacity - 1

    def push(self, item):
        if self.is_full():
            print("Stack Overflow")
        else:
            self.top += 1
            self.stack[self.top] = item

    def pop(self):
        if self.is_empty():
            print("Stack Underflow")
            return None
        else:
            item = self.stack[self.top]
            self.top -= 1
            return item

    def peek(self):
        if self.is_empty():
            print("Stack is empty")
            return None
        else:
            return self.stack[self.top]

    def size(self):
      return self.top + 1

# %%
st = Stack(6)

# %%
st.push(5)
st.size()
# Out:
# 1

# %%
st.capacity
# Out:
# 6

# %%
st.pop()
# Out:
# 5

# %%
st.capacity
# Out:
# 6

# %%
st.push(10)
st.pop()
st.peek()
# Out:
# 10

# %%
st.pop()
# Out:
# 10

# %%
st.top
# Out:
# -1

# %%
st.pop()
# Out:
# Stack Underflow

# %%
st.peek()
# Out:
# Stack is empty

# %%
st.size()
# Out:
# 0

# %%
st.capacity
st.stack
# Out:
# [10, 0, 0, 0, 0, 0]

# %%
st.top #pointer and intialize at -1
st.capacity #size of stack we are initialized
st.stack #give size of stack
# Out:
# -1

# %%
st.is_empty()
# Out:
# True
